# %%
import numpy as np
import pandas as pd
# Load the datasets
df = pd.read_csv("https://raw.githubusercontent.com/wongwara/Jobseeker_Baymax/main/dataset/listings2019_2022.csv")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3902 entries, 0 to 3901
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   jobId                  3902 non-null   int64
#  1   jobTitle               3902 non-null   object
#  2   jobClassification      3902 non-null   object
#  3   jobSubClassification   3902 non-null   object
#  4   advertiserName         3902 non-null   object
#  5   advertiserId           3902 non-null   int64
#  6   companyId              1067 non-null   float64
#  7   companyName            1476 non-null   object
#  8   companyRating          1067 non-null   float64
#  9   listingDate            3902 non-null   object
#  10  expiryDate             3902 non-null   object
#  11  teaser                 3374 non-null   object
#  12  nation                 3902 non-null   object
#  13  state                  3902 non-null   object
# ...

# %%
# df = df.drop(['jobId','jobTitle','advertiserName','advertiserId','companyId','companyName','companyRating','listingDate','expiryDate','city','area','suburb','companyProfileUrl','seekJobListingUrl','first_seen','last_seen','mobileAdTemplate'], axis=1)

# %%
df = df[['jobClassification','teaser','nation','workType','salary_string','isRightToWorkRequired','desktopAdTemplate',
         'Python','SQL','R','Tableau','SAS','Matlab','Hadoop','Spark','Java', 'Scala','recruiter']]

# %%
len(df['jobClassification'].unique())
# Out:
# 25

# %%
df = df[df['nation'].str.contains('Australia')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3897 entries, 0 to 3901
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   jobClassification      3897 non-null   object
#  1   teaser                 3369 non-null   object
#  2   nation                 3897 non-null   object
#  3   workType               3897 non-null   object
#  4   salary_string          1515 non-null   object
#  5   isRightToWorkRequired  3411 non-null   object
#  6   desktopAdTemplate      3203 non-null   object
#  7   Python                 3897 non-null   int64
#  8   SQL                    3897 non-null   int64
#  9   R                      3897 non-null   int64
#  10  Tableau                3897 non-null   int64
#  11  SAS                    3897 non-null   int64
#  12  Matlab                 3897 non-null   int64
#  13  Hadoop                 3897 non-null   int64
# ...

# %%
df = df.drop(['nation'],axis =1)

# %%
df.head()
# Out:
#                         jobClassification  \
# 0                    Science & Technology
# 1  Information & Communication Technology
# 2  Information & Communication Technology
# 3            Banking & Financial Services
# 4  Information & Communication Technology
#
#                                               teaser       workType  \
# 0  My client is a leading Australian-owned and ra...      Full Time
# 1  The Data Scientist will be responsible for mon...      Full Time
# 2  Fantastic organisation seeks experienced Insig...      Full Time
# 3  This role requires an individual with strong c...      Full Time
# 4  Our client, a large Sydney based telecommunica...  Contract/Temp
#
#                 salary_string isRightToWorkRequired  \
# 0                         NaN                     f
# 1                       Super                     t
# 2  $90000 - $120000 per annum                     f
# 3           $90k - $110k p.a.                     f
# ...

# %%
df.isna().sum()
# Out:
# jobClassification           0
# teaser                    528
# nation                      0
# workType                    0
# salary_string            2382
# isRightToWorkRequired     486
# desktopAdTemplate         694
# Python                      0
# SQL                         0
# R                           0
# Tableau                     0
# SAS                         0
# Matlab                      0
# Hadoop                      0
# Spark                       0
# Java                        0
# Scala                       0
# recruiter                   0
# dtype: int64

# %%
df = df.dropna(subset=['salary_string'])

# %%
df["salary_string"].describe
# Out:
# <bound method NDFrame.describe of 1                                                   Super
# 2                              $90000 - $120000 per annum
# 3                                       $90k - $110k p.a.
# 7           $110k - $120k p.a. + super + bonus + benefits
# 8                               Attractive Salary Package
#                               ...
# 3891                                    $700 - $1100 p.d.
# 3892    A leader in sustainability and renewable resou...
# 3893               $140k - $158k p.a. + bonus, discounts.
# 3897          Open to Quote (Sydney or Canberra Location)
# 3899                                      Desirable Rates
# Name: salary_string, Length: 1515, dtype: object>

# %%
# df.dropna()

# %%
unique_salary = df['salary_string'].unique()
len(unique_salary)
# Out:
# 889

# %%
unique_salary
# Out:
# array([nan, 'Super', '$90000 - $120000 per annum', '$90k - $110k p.a.',
#        '$110k - $120k p.a. + super + bonus + benefits',
#        'Attractive Salary Package',
#        '$71,509 - $90,215 per plus superannuation',
#        '$134421 - $148725 p.a. + plus up to 15.4% super',
#        '$120,000 - $159,999', 'Competitive remuneration ',
#        '$110k Package + Benefits', '80,000',
#        'Great Remuneration & Location + Organic Growth Opp', 'super',
#        'competitive', '$700 p/d', '$650 - $825 p.a. + competitive',
#        'APS6/EL1 hourly rate contract', '190,000', '$95k - $105k p.a.',
#        '$60,000 - $74,999', '$750 - $900 p.a. + competitive',
#        'up to $90,000', '$125000', '$100000 - $110000 per annum',
#        '$97k - $105k p.a. + up to 15.4% superannuation',
#        '$111k - $130k p.a. + up to 15.4% superannuation',
#        'including super', '$140K-$160K + Super + Bonus/Equity',
#        '£200000.00 - £300k p.a. + super, bonus and wider b',
# ...
